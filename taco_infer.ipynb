# %%
# !mkdir output

# %%
# %%writefile text.txt
# William Shakespeare was an English poet, playwright and actor,widely regarded as the greatest writer in the English language and the world's greatest dramatist. He is often called England's national poet and the "Bard of Avon".
# Out:
# Writing text.txt

# %%
# !python inference.py --tacotron2 gan_checkpoint/checkpoint_Tacotron2_1500 --max-decoder-steps 2000 --include-warmup -i text.txt --amp-run
# Out:
# DLL 2020-09-09 07:50:32.951160 - PARAMETER input : text.txt
# DLL 2020-09-09 07:50:32.951236 - PARAMETER output : parallel_output
# DLL 2020-09-09 07:50:32.951268 - PARAMETER suffix :
# DLL 2020-09-09 07:50:32.951298 - PARAMETER tacotron2 : gan_checkpoint/checkpoint_Tacotron2_1500
# DLL 2020-09-09 07:50:32.951324 - PARAMETER waveglow : None
# DLL 2020-09-09 07:50:32.951357 - PARAMETER sigma_infer : 0.9
# DLL 2020-09-09 07:50:32.951388 - PARAMETER denoising_strength : 0.01
# DLL 2020-09-09 07:50:32.951421 - PARAMETER sampling_rate : 22050
# DLL 2020-09-09 07:50:32.951452 - PARAMETER amp_run : True
# DLL 2020-09-09 07:50:32.951486 - PARAMETER log_file : nvlog.json
# DLL 2020-09-09 07:50:32.951516 - PARAMETER include_warmup : True
# DLL 2020-09-09 07:50:32.951546 - PARAMETER stft_hop_length : 256
# DLL 2020-09-09 07:50:32.951575 - PARAMETER feats_scp : None
# DLL 2020-09-09 07:50:32.951604 - PARAMETER dumpdir : mel
# DLL 2020-09-09 07:50:32.951633 - PARAMETER outdir : parallel_output
# DLL 2020-09-09 07:50:32.951662 - PARAMETER checkpoint : parallel_wavegan_checkpoint/checkpoint-110125steps.pkl
# DLL 2020-09-09 07:50:32.951692 - PARAMETER config : None
# DLL 2020-09-09 07:50:32.951721 - PARAMETER verbose : 1
# DLL 2020-09-09 07:50:32.951750 - PARAMETER model_name : Tacotron2_PyT
# WARNING:root:Dataset in hdf5 file already exists. recreate dataset in hdf5.
# Stopping after 651 decoder steps
# [decode]:   0%|                                           | 0/1 [00:00<?, ?it/s](2, 80, 651)
# [decode]: 100%|███████████████████████| 1/1 [00:00<00:00,  1.05it/s, RTF=0.0596]

# %%
import IPython.display as ipd
ipd.Audio('./output/audio_0_.wav', rate=22050)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
