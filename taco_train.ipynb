# %%
# !python -m multiproc train.py -m Tacotron2 -o ./output2/ -lr 1e-3 --epochs 1501 -bs 64 --weight-decay 1e-6 --grad-clip-thresh 1.0 --cudnn-enabled --log-file nvlog.json --anneal-steps 500 1000 1500 --anneal-factor 0.1 --amp-run
# Out:
# DLL 2020-03-26 08:09:44.288897 - PARAMETER output : ./output2/
# DLL 2020-03-26 08:09:44.289004 - PARAMETER dataset_path : ./
# DLL 2020-03-26 08:09:44.289049 - PARAMETER model_name : Tacotron2
# DLL 2020-03-26 08:09:44.289085 - PARAMETER log_file : nvlog.json
# DLL 2020-03-26 08:09:44.289118 - PARAMETER anneal_steps : ['500', '1000', '1500']
# DLL 2020-03-26 08:09:44.289155 - PARAMETER anneal_factor : 0.1
# DLL 2020-03-26 08:09:44.289188 - PARAMETER epochs : 1501
# DLL 2020-03-26 08:09:44.289221 - PARAMETER epochs_per_checkpoint : 10
# DLL 2020-03-26 08:09:44.289252 - PARAMETER checkpoint_path :
# DLL 2020-03-26 08:09:44.289282 - PARAMETER seed : 1234
# DLL 2020-03-26 08:09:44.289312 - PARAMETER dynamic_loss_scaling : True
# DLL 2020-03-26 08:09:44.289345 - PARAMETER amp_run : True
# DLL 2020-03-26 08:09:44.289376 - PARAMETER cudnn_enabled : True
# DLL 2020-03-26 08:09:44.289405 - PARAMETER cudnn_benchmark : False
# ...
